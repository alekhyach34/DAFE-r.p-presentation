# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
ecg_data = pd.read_csv("/content/MIT-BIH Arrhythmia Database.csv", index_col=0)

# %%
ecg_data.head()
# Out:
#        type  0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak  \
# record
# 101       N        76      313.0  0.074347 -0.160548  1.036401 -0.285662
# 101       N       313      315.0 -0.052079 -0.264784  0.886597 -0.366298
# 101       N       315      321.0 -0.062151 -0.296983  0.991859 -0.410306
# 101       N       321      336.0 -0.063322 -0.281386  1.034903 -0.403880
# 101       N       336      344.0 -0.062915  1.046914  1.046408  1.046408
#
#          0_qPeak  0_qrs_interval  0_pq_interval  ...   1_qPeak  \
# record                                           ...
# 101    -0.026824              41             18  ...  0.025930
# 101    -0.059710              21              4  ... -0.042009
# 101    -0.065686              22              3  ...  0.009528
# 101    -0.071750              22              4  ... -0.020536
# 101    -0.074639              11              4  ...  0.016053
#
#         1_qrs_interval  1_pq_interval  1_qt_interval  1_st_interval  \
# record
# ...

# %%
ecg_data
# Out:
#        type  0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak  \
# record
# 101       N        76      313.0  0.074347 -0.160548  1.036401 -0.285662
# 101       N       313      315.0 -0.052079 -0.264784  0.886597 -0.366298
# 101       N       315      321.0 -0.062151 -0.296983  0.991859 -0.410306
# 101       N       321      336.0 -0.063322 -0.281386  1.034903 -0.403880
# 101       N       336      344.0 -0.062915  1.046914  1.046408  1.046408
# ...     ...       ...        ...       ...       ...       ...       ...
# 234       N       240      241.0 -0.110230  1.420339  1.403346  1.403346
# 234       N       241      243.0 -0.119014  1.424782  1.420328  1.420328
# 234       N       243      252.0  0.173524 -0.443214  1.436878 -0.714642
# 234       N       252      244.0 -0.119820 -0.401522  1.337051 -0.688560
# 234       N       244      236.0  0.162909  1.416672  1.409440  1.409440
#
#          0_qPeak  0_qrs_interval  0_pq_interval  ...   1_qPeak  \
# ...

# %%
ecg_data["type"].unique()
# Out:
# array(['N', 'Q', 'SVEB', 'VEB', 'F'], dtype=object)

# %%
ecg_data["type"].nunique()
# Out:
# 5

# %%
ecg_data["type"].value_counts()
# Out:
# N       90083
# VEB      7009
# SVEB     2779
# F         803
# Q          15
# Name: type, dtype: int64

# %%
ecg_data.tail()
# Out:
#        type  0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak  \
# record
# 234       N       240      241.0 -0.110230  1.420339  1.403346  1.403346
# 234       N       241      243.0 -0.119014  1.424782  1.420328  1.420328
# 234       N       243      252.0  0.173524 -0.443214  1.436878 -0.714642
# 234       N       252      244.0 -0.119820 -0.401522  1.337051 -0.688560
# 234       N       244      236.0  0.162909  1.416672  1.409440  1.409440
#
#          0_qPeak  0_qrs_interval  0_pq_interval  ...   1_qPeak  \
# record                                           ...
# 234    -0.115682              14              3  ... -0.069234
# 234    -0.134406              13              5  ... -0.069530
# 234    -0.136431              38             21  ... -0.089396
# 234    -0.125076              27              5  ... -0.065487
# 234    -0.118397              28             21  ... -0.078260
#
#         1_qrs_interval  1_pq_interval  1_qt_interval  1_st_interval  \
# record
# ...

# %%
ecg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100689 entries, 101 to 234
# Data columns (total 33 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   type            100689 non-null  object
#  1   0_pre-RR        100689 non-null  int64
#  2   0_post-RR       100689 non-null  float64
#  3   0_pPeak         100689 non-null  float64
#  4   0_tPeak         100689 non-null  float64
#  5   0_rPeak         100689 non-null  float64
#  6   0_sPeak         100689 non-null  float64
#  7   0_qPeak         100689 non-null  float64
#  8   0_qrs_interval  100689 non-null  int64
#  9   0_pq_interval   100689 non-null  int64
#  10  0_qt_interval   100689 non-null  int64
#  11  0_st_interval   100689 non-null  int64
#  12  0_qrs_morph0    100689 non-null  float64
#  13  0_qrs_morph1    100689 non-null  float64
#  14  0_qrs_morph2    100689 non-null  float64
#  15  0_qrs_morph3    100689 non-null  float64
# ...

# %%
ecg_data.describe(percentiles=[0.5,0.65,1.0])
# Out:
#             0_pre-RR      0_post-RR        0_pPeak        0_tPeak  \
# count  100689.000000  100689.000000  100689.000000  100689.000000
# mean      279.400947     278.588207       0.049772       0.372262
# std        81.915453      81.124963       0.168789       0.739879
# min        11.000000       6.000000      -3.094391      -2.006422
# 50%       267.000000     266.000000       0.015865       0.240303
# 65%       300.000000     299.000000       0.062734       0.587693
# 100%     2114.000000    2114.000000       3.821118       4.118327
# max      2114.000000    2114.000000       3.821118       4.118327
#
#              0_rPeak        0_sPeak        0_qPeak  0_qrs_interval  \
# count  100689.000000  100689.000000  100689.000000   100689.000000
# mean        1.054485      -0.134376      -0.090466       28.326858
# std         0.617508       1.027590       0.189436       15.027789
# min        -2.372835      -3.622550      -3.871359        0.000000
# ...

# %%
ecg_data.nunique()
# Out:
# type                   5
# 0_pre-RR             773
# 0_post-RR            762
# 0_pPeak           100689
# 0_tPeak           100689
# 0_rPeak           100689
# 0_sPeak           100689
# 0_qPeak           100689
# 0_qrs_interval       149
# 0_pq_interval        106
# 0_qt_interval        272
# 0_st_interval        130
# 0_qrs_morph0      100689
# 0_qrs_morph1      100689
# 0_qrs_morph2      100689
# 0_qrs_morph3      100689
# 0_qrs_morph4      100689
# 1_pre-RR             773
# 1_post-RR            762
# 1_pPeak           100687
# 1_tPeak           100684
# 1_rPeak           100689
# 1_sPeak           100689
# 1_qPeak           100689
# 1_qrs_interval       143
# 1_pq_interval        133
# 1_qt_interval        252
# 1_st_interval        126
# 1_qrs_morph0      100689
# 1_qrs_morph1      100689
# 1_qrs_morph2      100689
# 1_qrs_morph3      100689
# 1_qrs_morph4      100689
# dtype: int64

# %%
ecg_data.duplicated()
# Out:
# record
# 101    False
# 101    False
# 101    False
# 101    False
# 101    False
#        ...
# 234    False
# 234    False
# 234    False
# 234    False
# 234    False
# Length: 100689, dtype: bool

# %%
ecg_data.count()
# Out:
# type              100689
# 0_pre-RR          100689
# 0_post-RR         100689
# 0_pPeak           100689
# 0_tPeak           100689
# 0_rPeak           100689
# 0_sPeak           100689
# 0_qPeak           100689
# 0_qrs_interval    100689
# 0_pq_interval     100689
# 0_qt_interval     100689
# 0_st_interval     100689
# 0_qrs_morph0      100689
# 0_qrs_morph1      100689
# 0_qrs_morph2      100689
# 0_qrs_morph3      100689
# 0_qrs_morph4      100689
# 1_pre-RR          100689
# 1_post-RR         100689
# 1_pPeak           100689
# 1_tPeak           100689
# 1_rPeak           100689
# 1_sPeak           100689
# 1_qPeak           100689
# 1_qrs_interval    100689
# 1_pq_interval     100689
# 1_qt_interval     100689
# 1_st_interval     100689
# 1_qrs_morph0      100689
# 1_qrs_morph1      100689
# 1_qrs_morph2      100689
# 1_qrs_morph3      100689
# 1_qrs_morph4      100689
# dtype: int64

# %%
ecg_data.type.count()
# Out:
# 100689

# %%
ecg_data
# Out:
#        type  0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak  \
# record
# 101       N        76      313.0  0.074347 -0.160548  1.036401 -0.285662
# 101       N       313      315.0 -0.052079 -0.264784  0.886597 -0.366298
# 101       N       315      321.0 -0.062151 -0.296983  0.991859 -0.410306
# 101       N       321      336.0 -0.063322 -0.281386  1.034903 -0.403880
# 101       N       336      344.0 -0.062915  1.046914  1.046408  1.046408
# ...     ...       ...        ...       ...       ...       ...       ...
# 234       N       240      241.0 -0.110230  1.420339  1.403346  1.403346
# 234       N       241      243.0 -0.119014  1.424782  1.420328  1.420328
# 234       N       243      252.0  0.173524 -0.443214  1.436878 -0.714642
# 234       N       252      244.0 -0.119820 -0.401522  1.337051 -0.688560
# 234       N       244      236.0  0.162909  1.416672  1.409440  1.409440
#
#          0_qPeak  0_qrs_interval  0_pq_interval  ...   1_qPeak  \
# ...

# %%
type=ecg_data['type'].value_counts()
type
# Out:
# N       90083
# VEB      7009
# SVEB     2779
# F         803
# Q          15
# Name: type, dtype: int64

# %%
lam=ecg_data.groupby('0_pre-RR')['type'].apply(lambda i: i.value_counts().idxmax())
lam
# Out:
# 0_pre-RR
# 11        N
# 20      VEB
# 24        N
# 26        N
# 27        N
#        ...
# 1588      N
# 1602      N
# 2022      N
# 2050      N
# 2114      N
# Name: type, Length: 773, dtype: object

# %%
la=ecg_data.groupby('0_post-RR')['type'].apply(lambda i: i.value_counts().idxmax())
la
# Out:
# 0_post-RR
# 6.0          N
# 15.0         N
# 17.0         N
# 22.0         N
# 25.0         N
#           ...
# 1588.0    SVEB
# 1602.0    SVEB
# 2022.0    SVEB
# 2050.0    SVEB
# 2114.0    SVEB
# Name: type, Length: 762, dtype: object

# %%
min_signal=ecg_data.groupby('0_pre-RR')['0_pPeak'].min()
max_signal=ecg_data.groupby('0_post-RR')['0_tPeak'].max()

# %%
signals_difference = max_signal-min_signal
significant_increase= signals_difference[signals_difference > 0]
num_significant_increase = len(significant_increase)
print(num_significant_increase)
# Out:
# 733

# %%
ecg_data.shape
# Out:
# (100689, 33)

# %%
ecg_data.size
# Out:
# 3322737

# %%
ecg_data.dropna()
# Out:
#        type  0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak  \
# record
# 101       N        76      313.0  0.074347 -0.160548  1.036401 -0.285662
# 101       N       313      315.0 -0.052079 -0.264784  0.886597 -0.366298
# 101       N       315      321.0 -0.062151 -0.296983  0.991859 -0.410306
# 101       N       321      336.0 -0.063322 -0.281386  1.034903 -0.403880
# 101       N       336      344.0 -0.062915  1.046914  1.046408  1.046408
# ...     ...       ...        ...       ...       ...       ...       ...
# 234       N       240      241.0 -0.110230  1.420339  1.403346  1.403346
# 234       N       241      243.0 -0.119014  1.424782  1.420328  1.420328
# 234       N       243      252.0  0.173524 -0.443214  1.436878 -0.714642
# 234       N       252      244.0 -0.119820 -0.401522  1.337051 -0.688560
# 234       N       244      236.0  0.162909  1.416672  1.409440  1.409440
#
#          0_qPeak  0_qrs_interval  0_pq_interval  ...   1_qPeak  \
# ...

# %%
ecg_data.describe(include=object)
# Out:
#           type
# count   100689
# unique       5
# top          N
# freq     90083

# %%
# Get the distinct values of each column
for column in ecg_data.columns:
    unique_val=ecg_data[column].unique()
    print("unique values of {} are {}".format(column,unique_val))
# Out:
# unique values of type are ['N' 'Q' 'SVEB' 'VEB' 'F']
# unique values of 0_pre-RR are [  76  313  315  321  336  344  324  310  329  330  323  326  319  328
#   325  305  302  320  309  307  295  293  285  290  288  283  272  274
#   303  279  286  291  300  304  301  294  282  297  332  322  331  317
#   316  314  334  327  318  312  306  299  308  311   65   92  289  278
#   196  276  270  292  296  284  277  298  287  273  280  340  219  217
#   335  339  341  338  337  357  345  346  349  354  361  351  343  360
#   352  363  362  365  364  342  369  372  358  333  366  359  356  348
#   381  374  370   24  264  368  355  367  376  347  384  194  426  380
#   353  379  378  373  371  390  391  382  350  389  377  383  385  388
#   387  375  392  414  396  393  395  386  237  459  399  122  267  246
#   252  269  268  164  195  200  178  431  177  167  485  192  422  188
#   170  463  189  467  172  458  179  175  488  184  472  182  173  442
# ...

# %%
#Filtering rows based on the presence of null values using the dropna() method:

filtered_dropna_2 = ecg_data.dropna(axis=1) # ==> columns with missing values are deleted

print("Total records Before:" , ecg_data.shape)
print("Total records After:" , filtered_dropna_2.shape)
# Out:
# Total records Before: (100689, 33)
# Total records After: (100689, 33)

# %%
dup_test = ecg_data[ecg_data.duplicated()]
dup_test.shape
# Out:
# (0, 33)

# %%
cols=ecg_data.loc[:,'type':'0_pre-RR']
cols
# Out:
#        type  0_pre-RR
# record
# 101       N        76
# 101       N       313
# 101       N       315
# 101       N       321
# 101       N       336
# ...     ...       ...
# 234       N       240
# 234       N       241
# 234       N       243
# 234       N       252
# 234       N       244
#
# [100689 rows x 2 columns]

# %%
ecg_data.dtypes
# Out:
# type               object
# 0_pre-RR            int64
# 0_post-RR         float64
# 0_pPeak           float64
# 0_tPeak           float64
# 0_rPeak           float64
# 0_sPeak           float64
# 0_qPeak           float64
# 0_qrs_interval      int64
# 0_pq_interval       int64
# 0_qt_interval       int64
# 0_st_interval       int64
# 0_qrs_morph0      float64
# 0_qrs_morph1      float64
# 0_qrs_morph2      float64
# 0_qrs_morph3      float64
# 0_qrs_morph4      float64
# 1_pre-RR            int64
# 1_post-RR         float64
# 1_pPeak           float64
# 1_tPeak           float64
# 1_rPeak           float64
# 1_sPeak           float64
# 1_qPeak           float64
# 1_qrs_interval      int64
# 1_pq_interval       int64
# 1_qt_interval       int64
# 1_st_interval       int64
# 1_qrs_morph0      float64
# 1_qrs_morph1      float64
# 1_qrs_morph2      float64
# 1_qrs_morph3      float64
# 1_qrs_morph4      float64
# dtype: object

# %%
filterd_num=ecg_data.select_dtypes(include='int').iloc[0:5,:]
filterd_num
# Out:
#         0_pre-RR  0_qrs_interval  0_pq_interval  0_qt_interval  0_st_interval  \
# record
# 101           76              41             18             66              7
# 101          313              21              4             33              8
# 101          315              22              3             32              7
# 101          321              22              4             33              7
# 101          336              11              4             16              1
#
#         1_pre-RR  1_qrs_interval  1_pq_interval  1_qt_interval  1_st_interval
# record
# 101           76               2             18             22              2
# 101          313              26             27             62              9
# 101          315               3              8             12              1
# 101          321               6              9             16              1
# 101          336              16              5             31             10

# %%
filterd_num=ecg_data.select_dtypes(include='number').iloc[0:5,:]
filterd_num
# Out:
#         0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak   0_qPeak  \
# record
# 101           76      313.0  0.074347 -0.160548  1.036401 -0.285662 -0.026824
# 101          313      315.0 -0.052079 -0.264784  0.886597 -0.366298 -0.059710
# 101          315      321.0 -0.062151 -0.296983  0.991859 -0.410306 -0.065686
# 101          321      336.0 -0.063322 -0.281386  1.034903 -0.403880 -0.071750
# 101          336      344.0 -0.062915  1.046914  1.046408  1.046408 -0.074639
#
#         0_qrs_interval  0_pq_interval  0_qt_interval  ...   1_qPeak  \
# record                                                ...
# 101                 41             18             66  ...  0.025930
# 101                 21              4             33  ... -0.042009
# 101                 22              3             32  ...  0.009528
# 101                 22              4             33  ... -0.020536
# 101                 11              4             16  ...  0.016053
#
# ...

# %%
filterd_obj=ecg_data.select_dtypes(include='object').iloc[0:4,:]
filterd_obj
# Out:
#        type
# record
# 101       N
# 101       N
# 101       N
# 101       N

# %%
filterd_obj=ecg_data.select_dtypes(include='float').iloc[0:4,:]
filterd_obj
# Out:
#         0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak   0_qPeak  \
# record
# 101         313.0  0.074347 -0.160548  1.036401 -0.285662 -0.026824
# 101         315.0 -0.052079 -0.264784  0.886597 -0.366298 -0.059710
# 101         321.0 -0.062151 -0.296983  0.991859 -0.410306 -0.065686
# 101         336.0 -0.063322 -0.281386  1.034903 -0.403880 -0.071750
#
#         0_qrs_morph0  0_qrs_morph1  0_qrs_morph2  0_qrs_morph3  ...   1_pPeak  \
# record                                                          ...
# 101        -0.026824     -0.001236      0.016659      0.143241  ...  0.038310
# 101        -0.059710      0.104030      0.691891      0.805549  ...  0.014264
# 101        -0.065686      0.051459      0.630419      0.890794  ...  0.021311
# 101        -0.071750      0.059376      0.652814      0.948490  ... -0.000665
#
#          1_tPeak   1_rPeak   1_sPeak   1_qPeak  1_qrs_morph0  1_qrs_morph1  \
# record
# ...
